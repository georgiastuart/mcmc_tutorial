# %%
import numpy as np
import seaborn as sb
from pymc3 import hpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-998d4b750d1b> in <module>
#       1 import numpy as np
#       2 import seaborn as sb
# ----> 3 from pymc3 import hpd
#
# ModuleNotFoundError: No module named 'pymc3'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
@np.vectorize
def exponential(x):
    return 1.5 * np.exp(-1.5 * x)

# %%
xvals = np.linspace(0, 5, 100)

# %%
plt.plot(xvals, exponential(xvals))
plt.xlabel('x')
plt.ylabel('Density')
plt.savefig('exponential.svg')

# %%
sample1 = np.random.chisquare(3, 50)
sample2 = np.random.chisquare(3, 500)

# %%
fig, ax = plt.subplots(2, 1, sharex=True, sharey=True, figsize=(5, 5))
sb.distplot(sample1, rug=True, ax=ax[0])
sb.distplot(sample2, rug=True, ax=ax[1])
fig.savefig("kde.svg")
